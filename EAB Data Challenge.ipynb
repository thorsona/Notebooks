# %%
import numpy as np
import pandas as pd
import scipy.stats as ss
import matplotlib
import matplotlib.pyplot as plt
import seaborn as sns
import pickle
import time
import os
import random
pd.options.display.max_rows = 1000
os.chdir('C:/Users/Anna/Documents/EAB_Skill_Test/')

# %%
# importing raw data, looking at it
raw = pd.read_csv('airline_data.csv')
raw.head().T
# Out:
#                                  0            1                2           3  \
# DAY_OF_WEEK                      1            1                1           1
# FL_DATE                 2016-01-04   2016-01-04       2016-01-04  2016-01-04
# UNIQUE_CARRIER                  F9           F9               F9          F9
# AIRLINE_ID                   20436        20436            20436       20436
# FL_NUM                         141          142              402         612
# ORIGIN_AIRPORT_ID            11292        14747            12892       11292
# ORIGIN_CITY_MARKET_ID        30325        30559            32575       30325
# ORIGIN                         DEN          SEA              LAX         DEN
# ORIGIN_CITY_NAME        Denver, CO  Seattle, WA  Los Angeles, CA  Denver, CO
# ORIGIN_STATE_ABR                CO           WA               CA          CO
# ORIGIN_WAC                      82           93               91          82
# DEST_AIRPORT_ID              14747        11292            11292       13303
# DEST_CITY_MARKET_ID          30559        30325            30325       32467
# DEST                           SEA          DEN              DEN         MIA
# DEST_CITY_NAME         Seattle, WA   Denver, CO       Denver, CO   Miami, FL
# DEST_STATE_ABR                  WA           CO               CO          FL
# DEST_WAC                        93           82               82          33
# CRS_DEP_TIME                  1645         1930             1810        2255
# DEP_TIME                      1657         1926             1754        2252
# DEP_DELAY                       12           -4              -16          -3
# DEP_DELAY_NEW                   12            0                0           0
# TAXI_OUT                        10           26               16          14
# WHEELS_OFF                    1707         1952             1810        2306
# WHEELS_ON                     1827         2303             2103         427
# TAXI_IN                         10           13                8           7
# CRS_ARR_TIME                  1845         2310             2126         433
# ARR_TIME                      1837         2316             2111         434
# ARR_DELAY                       -8            6              -15           1
# CANCELLED                        0            0                0           0
# CANCELLATION_CODE              NaN          NaN              NaN         NaN
# DIVERTED                         0            0                0           0
# CRS_ELAPSED_TIME               180          160              136         218
# ACTUAL_ELAPSED_TIME            160          170              137         222
# AIR_TIME                       140          131              113         201
# FLIGHTS                          1            1                1           1
# DISTANCE                      1024         1024              862        1709
# CARRIER_DELAY                  NaN          NaN              NaN         NaN
# WEATHER_DELAY                  NaN          NaN              NaN         NaN
# NAS_DELAY                      NaN          NaN              NaN         NaN
# SECURITY_DELAY                 NaN          NaN              NaN         NaN
# LATE_AIRCRAFT_DELAY            NaN          NaN              NaN         NaN
# FIRST_DEP_TIME                 NaN          NaN              NaN         NaN
# TOTAL_ADD_GTIME                NaN          NaN              NaN         NaN
# LONGEST_ADD_GTIME              NaN          NaN              NaN         NaN
# DIV_AIRPORT_LANDINGS             0            0                0           0
# DIV_REACHED_DEST               NaN          NaN              NaN         NaN
# DIV_DISTANCE                   NaN          NaN              NaN         NaN
# Unnamed: 47                    NaN          NaN              NaN         NaN
#
#                                  4
# DAY_OF_WEEK                      1
# FL_DATE                 2016-01-04
# UNIQUE_CARRIER                  F9
# AIRLINE_ID                   20436
# FL_NUM                        1152
# ORIGIN_AIRPORT_ID            10397
# ORIGIN_CITY_MARKET_ID        30397
# ORIGIN                         ATL
# ORIGIN_CITY_NAME       Atlanta, GA
# ORIGIN_STATE_ABR                GA
# ORIGIN_WAC                      34
# DEST_AIRPORT_ID              13204
# DEST_CITY_MARKET_ID          31454
# DEST                           MCO
# DEST_CITY_NAME         Orlando, FL
# DEST_STATE_ABR                  FL
# DEST_WAC                        33
# CRS_DEP_TIME                   840
# DEP_TIME                       844
# DEP_DELAY                        4
# DEP_DELAY_NEW                    4
# TAXI_OUT                        12
# WHEELS_OFF                     856
# WHEELS_ON                      958
# TAXI_IN                          6
# CRS_ARR_TIME                  1005
# ARR_TIME                      1004
# ARR_DELAY                       -1
# CANCELLED                        0
# CANCELLATION_CODE              NaN
# DIVERTED                         0
# CRS_ELAPSED_TIME                85
# ACTUAL_ELAPSED_TIME             80
# AIR_TIME                        62
# FLIGHTS                          1
# DISTANCE                       404
# CARRIER_DELAY                  NaN
# WEATHER_DELAY                  NaN
# NAS_DELAY                      NaN
# SECURITY_DELAY                 NaN
# LATE_AIRCRAFT_DELAY            NaN
# FIRST_DEP_TIME                 NaN
# TOTAL_ADD_GTIME                NaN
# LONGEST_ADD_GTIME              NaN
# DIV_AIRPORT_LANDINGS             0
# DIV_REACHED_DEST               NaN
# DIV_DISTANCE                   NaN
# Unnamed: 47                    NaN

# %%
## take a look at data and see what has nulls, what the distribution looks like, etc
raw.describe().T
# Out:
# C:\Anaconda2\lib\site-packages\numpy\lib\function_base.py:3834: RuntimeWarning: Invalid value encountered in percentile
#   RuntimeWarning)
#                           count          mean          std      min      25%  \
# DAY_OF_WEEK            445827.0      4.113815     2.005007      1.0      2.0
# AIRLINE_ID             445827.0  19903.085069   382.853084  19393.0  19790.0
# FL_NUM                 445827.0   2078.856456  1757.269780      1.0    702.0
# ORIGIN_AIRPORT_ID      445827.0  12682.120789  1529.485604  10135.0  11292.0
# ORIGIN_CITY_MARKET_ID  445827.0  31723.938281  1280.460591  30070.0  30615.0
# ORIGIN_WAC             445827.0     55.652430    26.951340      1.0     34.0
# DEST_AIRPORT_ID        445827.0  12681.700924  1529.329960  10135.0  11292.0
# DEST_CITY_MARKET_ID    445827.0  31723.664890  1280.213952  30070.0  30615.0
# DEST_WAC               445827.0     55.652870    26.949279      1.0     34.0
# CRS_DEP_TIME           445827.0   1330.384387   482.809711      1.0    920.0
# DEP_TIME               434354.0   1334.236268   492.955466      1.0      NaN
# DEP_DELAY              434354.0      7.793537    36.833007    -47.0      NaN
# DEP_DELAY_NEW          434354.0     10.774681    35.780277      0.0      NaN
# TAXI_OUT               434227.0     16.449422     9.169353      1.0      NaN
# WHEELS_OFF             434227.0   1356.554065   493.866371      1.0      NaN
# WHEELS_ON              433920.0   1483.300601   514.352310      1.0      NaN
# TAXI_IN                433920.0      7.294298     5.437682      1.0      NaN
# CRS_ARR_TIME           445827.0   1502.951591   505.240190      1.0   1118.0
# ARR_TIME               433920.0   1488.101445   518.681533      1.0      NaN
# ARR_DELAY              433298.0      1.533654    39.096842    -79.0      NaN
# CANCELLED              445827.0      0.026165     0.159626      0.0      0.0
# DIVERTED               445827.0      0.001938     0.043980      0.0      0.0
# CRS_ELAPSED_TIME       445827.0    146.499142    76.606607     21.0     90.0
# ACTUAL_ELAPSED_TIME    433298.0    140.135200    74.753951     15.0      NaN
# AIR_TIME               433298.0    116.395818    72.981191      8.0      NaN
# FLIGHTS                445827.0      1.000000     0.000000      1.0      1.0
# DISTANCE               445827.0    844.233880   610.349957     31.0    391.0
# CARRIER_DELAY           70882.0     20.921912    57.041917      0.0      NaN
# WEATHER_DELAY           70882.0      2.836573    23.306995      0.0      NaN
# NAS_DELAY               70882.0     12.680455    24.859425      0.0      NaN
# SECURITY_DELAY          70882.0      0.080415     2.070844      0.0      NaN
# LATE_AIRCRAFT_DELAY     70882.0     21.635450    41.991917      0.0      NaN
# FIRST_DEP_TIME           2552.0   1236.022335   513.040425      6.0      NaN
# TOTAL_ADD_GTIME          2552.0     32.054075    25.993098      1.0      NaN
# LONGEST_ADD_GTIME        2552.0     31.776254    25.698255      1.0      NaN
# DIV_AIRPORT_LANDINGS   445827.0      0.003261     0.117348      0.0      0.0
# DIV_REACHED_DEST          864.0      0.719907     0.449304      0.0      NaN
# DIV_DISTANCE              864.0     81.964120   247.294102      0.0      NaN
# Unnamed: 47                 0.0           NaN          NaN      NaN      NaN
#
#                            50%      75%      max
# DAY_OF_WEEK                4.0      6.0      7.0
# AIRLINE_ID             19805.0  20304.0  21171.0
# FL_NUM                  1594.0   2763.0   7438.0
# ORIGIN_AIRPORT_ID      12889.0  14027.0  16218.0
# ORIGIN_CITY_MARKET_ID  31453.0  32467.0  35991.0
# ORIGIN_WAC                52.0     82.0     93.0
# DEST_AIRPORT_ID        12889.0  14027.0  16218.0
# DEST_CITY_MARKET_ID    31453.0  32467.0  35991.0
# DEST_WAC                  52.0     82.0     93.0
# CRS_DEP_TIME            1325.0   1730.0   2359.0
# DEP_TIME                   NaN      NaN   2400.0
# DEP_DELAY                  NaN      NaN   1663.0
# DEP_DELAY_NEW              NaN      NaN   1663.0
# TAXI_OUT                   NaN      NaN    158.0
# WHEELS_OFF                 NaN      NaN   2400.0
# WHEELS_ON                  NaN      NaN   2400.0
# TAXI_IN                    NaN      NaN    155.0
# CRS_ARR_TIME            1527.0   1920.0   2359.0
# ARR_TIME                   NaN      NaN   2400.0
# ARR_DELAY                  NaN      NaN   1659.0
# CANCELLED                  0.0      0.0      1.0
# DIVERTED                   0.0      0.0      1.0
# CRS_ELAPSED_TIME         128.0    180.0    705.0
# ACTUAL_ELAPSED_TIME        NaN      NaN    721.0
# AIR_TIME                   NaN      NaN    698.0
# FLIGHTS                    1.0      1.0      1.0
# DISTANCE                 679.0   1086.0   4983.0
# CARRIER_DELAY              NaN      NaN   1659.0
# WEATHER_DELAY              NaN      NaN   1093.0
# NAS_DELAY                  NaN      NaN    755.0
# SECURITY_DELAY             NaN      NaN    242.0
# LATE_AIRCRAFT_DELAY        NaN      NaN   1158.0
# FIRST_DEP_TIME             NaN      NaN   2354.0
# TOTAL_ADD_GTIME            NaN      NaN    176.0
# LONGEST_ADD_GTIME          NaN      NaN    176.0
# DIV_AIRPORT_LANDINGS       0.0      0.0      9.0
# DIV_REACHED_DEST           NaN      NaN      1.0
# DIV_DISTANCE               NaN      NaN   2614.0
# Unnamed: 47                NaN      NaN      NaN

# %%
## make dummy vars for categorical features (ids, cities, day of week, etc)
## first take a look at how many we'd have to make
raw = raw.drop([], axis=1)
cols = []
for c in raw.columns:
    if 'ID' in c or 'STATE' in c or 'WAC' in c or 'DAY' in c:
        cols.append(c)
    elif c == 'UNIQUE_CARRIER':
        cols.append(c)
for c in cols:
    print 'Unique values for '+str(c)+': {}'.format(len(raw[c].unique()))
# Out:
# Unique values for DAY_OF_WEEK: 7
# Unique values for UNIQUE_CARRIER: 12
# Unique values for AIRLINE_ID: 12
# Unique values for ORIGIN_AIRPORT_ID: 294
# Unique values for ORIGIN_CITY_MARKET_ID: 273
# Unique values for ORIGIN_STATE_ABR: 52
# Unique values for ORIGIN_WAC: 52
# Unique values for DEST_AIRPORT_ID: 294
# Unique values for DEST_CITY_MARKET_ID: 273
# Unique values for DEST_STATE_ABR: 52
# Unique values for DEST_WAC: 52

# %%
## checking to see if these variables are duplicates
print len(raw.groupby(['DEST_STATE_ABR', 'DEST_WAC']))
print len(raw.groupby(['AIRLINE_ID','UNIQUE_CARRIER']))
# Out:
# 52
# 12

# %%
## okay, so for some of these we'd have to make hundreds of new variables
# let's be a bit selective here
cols = ['DEST_WAC', 'ORIGIN_WAC', 'AIRLINE_ID']
for col_name in cols:
    print 'Making '+str(col_name)+' vars at '+time.strftime("%a, %d %b %Y %H:%M:%S", time.localtime())
    for a in raw[col_name].unique():
        raw[str(col_name)+str(a)] = raw[col_name].map(lambda x: x == a).astype(int)
# Out:
# Making DEST_WAC vars at Mon, 17 Oct 2016 07:55:47
# Making ORIGIN_WAC vars at Mon, 17 Oct 2016 07:56:00
# Making AIRLINE_ID vars at Mon, 17 Oct 2016 07:56:12

# %%
## remove nulls from training data
data = raw[raw.ARR_DELAY.notnull()].copy()

##take a pseudo-random subsample of the data for training
sample = random.sample(data.index, 50000)
data = data[data.index.isin(sample)]
len(data)
# Out:
# 50000

# %%
# columns that we want to drop
x_drop_cols = ['Unnamed: 47','DEST','ORIGIN','FL_NUM','DEP_DELAY_NEW','DEP_DELAY','ORIGIN_AIRPORT_ID', 'ORIGIN_CITY_MARKET_ID', 
               'ORIGIN_CITY_NAME', 'DEST_AIRPORT_ID', 'DEST_CITY_MARKET_ID','DEST_CITY_NAME', 'ORIGIN_STATE_ABR',
               'DEST_STATE_ABR','ARR_DELAY','CARRIER_DELAY','NAS_DELAY','WEATHER_DELAY','SECURITY_DELAY',
               'LATE_AIRCRAFT_DELAY'] + cols

# drop columns, fill nulls with training data with zero (yes this is lazy - if i had more time i might mean-fill or something)
X = data.drop(x_drop_cols, axis=1).fillna(0).select_dtypes(exclude=[object])

# using DEP_DELAY instead of DEP_DELAY_NEW since we're interested in the number of minutes (positive or negative)
y = data['ARR_DELAY']

## split into training (60%) and test (40%) sets
## may end wanting to take a random subsample if the training gets too CPU-intensive
from sklearn.cross_validation import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.4, random_state=21)

# %%
## how many features are we starting with?
len(X_train.columns)
# Out:
# 139

# %%
## look at y data again now that we've removed nulls
y_train.describe().T
# Out:
# count    30000.000000
# mean         1.591933
# std         39.290994
# min        -75.000000
# 25%        -15.000000
# 50%         -7.000000
# 75%          5.000000
# max       1237.000000
# Name: ARR_DELAY, dtype: float64

# %%
## look at features again 
X_train.describe().T
# Out:
#                         count         mean         std   min     25%     50%  \
# DAY_OF_WEEK           30000.0     4.090400    1.992677   1.0     2.0     4.0
# CRS_DEP_TIME          30000.0  1330.041967  481.274350   5.0   920.0  1329.0
# DEP_TIME              30000.0  1334.636633  491.316672   1.0   925.0  1332.0
# TAXI_OUT              30000.0    16.377867    9.084245   2.0    11.0    14.0
# WHEELS_OFF            30000.0  1357.193167  491.904302   1.0   940.0  1344.0
# WHEELS_ON             30000.0  1484.904000  513.096568   1.0  1105.0  1521.0
# TAXI_IN               30000.0     7.286767    5.430873   1.0     4.0     6.0
# CRS_ARR_TIME          30000.0  1502.909500  504.644729   1.0  1118.0  1530.0
# ARR_TIME              30000.0  1488.908100  517.875274   1.0  1109.0  1524.0
# CANCELLED             30000.0     0.000000    0.000000   0.0     0.0     0.0
# CANCELLATION_CODE     30000.0     0.000000    0.000000   0.0     0.0     0.0
# DIVERTED              30000.0     0.000000    0.000000   0.0     0.0     0.0
# CRS_ELAPSED_TIME      30000.0   146.408200   77.061910  21.0    89.0   128.0
# ACTUAL_ELAPSED_TIME   30000.0   140.168133   75.405439  20.0    84.0   122.0
# AIR_TIME              30000.0   116.503500   73.611857   8.0    62.0    97.0
# FLIGHTS               30000.0     1.000000    0.000000   1.0     1.0     1.0
# DISTANCE              30000.0   844.438333  615.074376  31.0   390.0   678.0
# FIRST_DEP_TIME        30000.0     6.977933   99.378948   0.0     0.0     0.0
# TOTAL_ADD_GTIME       30000.0     0.180533    2.985382   0.0     0.0     0.0
# LONGEST_ADD_GTIME     30000.0     0.180533    2.985382   0.0     0.0     0.0
# DIV_AIRPORT_LANDINGS  30000.0     0.000000    0.000000   0.0     0.0     0.0
# DIV_REACHED_DEST      30000.0     0.000000    0.000000   0.0     0.0     0.0
# DIV_DISTANCE          30000.0     0.000000    0.000000   0.0     0.0     0.0
# DEST_WAC93            30000.0     0.023500    0.151479   0.0     0.0     0.0
# DEST_WAC82            30000.0     0.045233    0.207859   0.0     0.0     0.0
# DEST_WAC33            30000.0     0.091900    0.288894   0.0     0.0     0.0
# DEST_WAC34            30000.0     0.070800    0.256482   0.0     0.0     0.0
# DEST_WAC91            30000.0     0.128733    0.334939   0.0     0.0     0.0
# DEST_WAC23            30000.0     0.018600    0.135100   0.0     0.0     0.0
# DEST_WAC22            30000.0     0.045100    0.207534   0.0     0.0     0.0
# ACTUAL_ELAPSED_TIME    174.0   721.0
# AIR_TIME               149.0   695.0
# FLIGHTS                  1.0     1.0
# DISTANCE              1085.0  4983.0
# FIRST_DEP_TIME           0.0  2346.0
# TOTAL_ADD_GTIME          0.0   121.0
# LONGEST_ADD_GTIME        0.0   121.0
# DIV_AIRPORT_LANDINGS     0.0     0.0
# DIV_REACHED_DEST         0.0     0.0
# DIV_DISTANCE             0.0     0.0
# DEST_WAC93               0.0     1.0
# DEST_WAC82               0.0     1.0
# DEST_WAC33               0.0     1.0
# DEST_WAC34               0.0     1.0
# DEST_WAC91               0.0     1.0
# DEST_WAC23               0.0     1.0
# DEST_WAC22               0.0     1.0
# DEST_WAC41               0.0     1.0
# DEST_WAC81               0.0     1.0
# DEST_WAC38               0.0     1.0
# DEST_WAC74               0.0     1.0
# DEST_WAC87               0.0     1.0
# DEST_WAC85               0.0     1.0
# DEST_WAC92               0.0     1.0
# DEST_WAC64               0.0     1.0
# DEST_WAC54               0.0     1.0
# DEST_WAC63               0.0     1.0
# DEST_WAC44               0.0     1.0
# DEST_WAC52               0.0     1.0
# DEST_WAC42               0.0     1.0
# DEST_WAC43               0.0     1.0
# DEST_WAC45               0.0     1.0
# DEST_WAC84               0.0     1.0
# DEST_WAC36               0.0     1.0
# DEST_WAC21               0.0     1.0
# DEST_WAC72               0.0     1.0
# DEST_WAC65               0.0     1.0
# DEST_WAC61               0.0     1.0
# DEST_WAC2                0.0     1.0
# DEST_WAC35               0.0     1.0
# DEST_WAC37               0.0     1.0
# DEST_WAC13               0.0     1.0
# DEST_WAC5                0.0     1.0
# DEST_WAC3                0.0     1.0
# DEST_WAC53               0.0     1.0
# DEST_WAC73               0.0     1.0
# DEST_WAC62               0.0     1.0
# DEST_WAC71               0.0     1.0
# DEST_WAC66               0.0     1.0
# DEST_WAC67               0.0     1.0
# DEST_WAC83               0.0     1.0
# DEST_WAC51               0.0     1.0
# DEST_WAC4                0.0     1.0
# DEST_WAC86               0.0     1.0
# DEST_WAC88               0.0     1.0
# DEST_WAC16               0.0     1.0
# DEST_WAC11               0.0     1.0
# DEST_WAC15               0.0     1.0
# DEST_WAC1                0.0     1.0
# DEST_WAC14               0.0     1.0
# DEST_WAC12               0.0     1.0
# DEST_WAC39               0.0     1.0
# ORIGIN_WAC82             0.0     1.0
# ORIGIN_WAC93             0.0     1.0
# ORIGIN_WAC91             0.0     1.0
# ORIGIN_WAC34             0.0     1.0
# ORIGIN_WAC33             0.0     1.0
# ORIGIN_WAC23             0.0     1.0
# ORIGIN_WAC22             0.0     1.0
# ORIGIN_WAC41             0.0     1.0
# ORIGIN_WAC81             0.0     1.0
# ORIGIN_WAC38             0.0     1.0
# ORIGIN_WAC74             0.0     1.0
# ORIGIN_WAC87             0.0     1.0
# ORIGIN_WAC85             0.0     1.0
# ORIGIN_WAC63             0.0     1.0
# ORIGIN_WAC92             0.0     1.0
# ORIGIN_WAC64             0.0     1.0
# ORIGIN_WAC54             0.0     1.0
# ORIGIN_WAC44             0.0     1.0
# ORIGIN_WAC42             0.0     1.0
# ORIGIN_WAC52             0.0     1.0
# ORIGIN_WAC43             0.0     1.0
# ORIGIN_WAC45             0.0     1.0
# ORIGIN_WAC84             0.0     1.0
# ORIGIN_WAC36             0.0     1.0
# ORIGIN_WAC21             0.0     1.0
# ORIGIN_WAC72             0.0     1.0
# ORIGIN_WAC65             0.0     1.0
# ORIGIN_WAC61             0.0     1.0
# ORIGIN_WAC2              0.0     1.0
# ORIGIN_WAC37             0.0     1.0
# ORIGIN_WAC35             0.0     1.0
# ORIGIN_WAC13             0.0     1.0
# ORIGIN_WAC5              0.0     1.0
# ORIGIN_WAC3              0.0     1.0
# ORIGIN_WAC51             0.0     1.0
# ORIGIN_WAC71             0.0     1.0
# ORIGIN_WAC73             0.0     1.0
# ORIGIN_WAC86             0.0     1.0
# ORIGIN_WAC62             0.0     1.0
# ORIGIN_WAC66             0.0     1.0
# ORIGIN_WAC83             0.0     1.0
# ORIGIN_WAC67             0.0     1.0
# ORIGIN_WAC88             0.0     1.0
# ORIGIN_WAC4              0.0     1.0
# ORIGIN_WAC11             0.0     1.0
# ORIGIN_WAC16             0.0     1.0
# ORIGIN_WAC15             0.0     1.0
# ORIGIN_WAC1              0.0     1.0
# ORIGIN_WAC14             0.0     1.0
# ORIGIN_WAC12             0.0     1.0
# ORIGIN_WAC53             0.0     1.0
# ORIGIN_WAC39             0.0     1.0
# AIRLINE_ID20436          0.0     1.0
# AIRLINE_ID19690          0.0     1.0
# AIRLINE_ID20416          0.0     1.0
# AIRLINE_ID20366          0.0     1.0
# AIRLINE_ID20304          0.0     1.0
# AIRLINE_ID19977          0.0     1.0
# AIRLINE_ID21171          0.0     1.0
# AIRLINE_ID19393          0.0     1.0
# AIRLINE_ID19790          0.0     1.0
# AIRLINE_ID19805          0.0     1.0
# AIRLINE_ID19930          0.0     1.0
# AIRLINE_ID20409          0.0     1.0

# %%
## Not all of the potential variables will be useful, let's trim this down
## using sklearn's feature selection function
from sklearn.feature_selection import SelectFromModel
from sklearn.ensemble import RandomForestRegressor
rfr = RandomForestRegressor(n_estimators = 50) 

select = SelectFromModel(estimator=rfr, threshold = 0.001, prefit=False)
select.fit_transform(X_train,y_train)
features = select.get_support()
x_train = X_train[X_train.columns[features]]
print rfr
print X_train.columns[features]
print 'number of features: {}'.format(len(X_train.columns[features]))
# Out:
# RandomForestRegressor(bootstrap=True, criterion='mse', max_depth=None,
#            max_features='auto', max_leaf_nodes=None, min_samples_leaf=1,
#            min_samples_split=2, min_weight_fraction_leaf=0.0,
#            n_estimators=50, n_jobs=1, oob_score=False, random_state=None,
#            verbose=0, warm_start=False)
# Index([u'DAY_OF_WEEK', u'CRS_DEP_TIME', u'DEP_TIME', u'TAXI_OUT',
#        u'WHEELS_OFF', u'WHEELS_ON', u'TAXI_IN', u'CRS_ARR_TIME', u'ARR_TIME',
#        u'CRS_ELAPSED_TIME', u'ACTUAL_ELAPSED_TIME', u'AIR_TIME', u'DISTANCE',
#        u'FIRST_DEP_TIME', u'TOTAL_ADD_GTIME', u'LONGEST_ADD_GTIME',
#        u'DEST_WAC33', u'DEST_WAC34', u'DEST_WAC91', u'DEST_WAC54',
#        u'DEST_WAC63', u'DEST_WAC2', u'DEST_WAC51', u'ORIGIN_WAC91',
#        u'ORIGIN_WAC34', u'ORIGIN_WAC41', u'ORIGIN_WAC63', u'ORIGIN_WAC64',
#        u'ORIGIN_WAC54', u'ORIGIN_WAC44', u'ORIGIN_WAC45', u'ORIGIN_WAC4',
#        u'AIRLINE_ID20416', u'AIRLINE_ID20366', u'AIRLINE_ID20304',
#        u'AIRLINE_ID19393', u'AIRLINE_ID19790', u'AIRLINE_ID19805'],
#       dtype='object')
# number of features: 38

# %%
# fit the model
rfrmodel = rfr.fit(x_train, y_train)

# %%
# get predictions for the test data
x_test = X_test[X_test.columns[features]]
preds = rfr.predict(x_test)

# %%
# take a look at feature importances
importances = [pd.DataFrame(x_train.columns), pd.DataFrame(rfr.feature_importances_)]
importances = pd.concat(importances, axis=1)
print importances
# Out:
#                       0         0
# 0           DAY_OF_WEEK  0.005910
# 1          CRS_DEP_TIME  0.102027
# 2              DEP_TIME  0.030683
# 3              TAXI_OUT  0.070086
# 4            WHEELS_OFF  0.031816
# 5             WHEELS_ON  0.072892
# 6               TAXI_IN  0.021036
# 7          CRS_ARR_TIME  0.362014
# 8              ARR_TIME  0.147626
# 9      CRS_ELAPSED_TIME  0.015107
# 10  ACTUAL_ELAPSED_TIME  0.011566
# 11             AIR_TIME  0.010068
# 12             DISTANCE  0.008493
# 13       FIRST_DEP_TIME  0.007638
# 14      TOTAL_ADD_GTIME  0.025000
# 15    LONGEST_ADD_GTIME  0.021060
# 16           DEST_WAC33  0.000951
# 17           DEST_WAC34  0.000980
# 18           DEST_WAC91  0.001320
# 19           DEST_WAC54  0.015810
# 20           DEST_WAC63  0.001223
# 21            DEST_WAC2  0.001211
# 22           DEST_WAC51  0.004583
# 23         ORIGIN_WAC91  0.001779
# 24         ORIGIN_WAC34  0.001233
# 25         ORIGIN_WAC41  0.003334
# 26         ORIGIN_WAC63  0.001162
# 27         ORIGIN_WAC64  0.000226
# 28         ORIGIN_WAC54  0.000851
# 29         ORIGIN_WAC44  0.007547
# 30         ORIGIN_WAC45  0.005509
# 31          ORIGIN_WAC4  0.001189
# 32      AIRLINE_ID20416  0.001369
# 33      AIRLINE_ID20366  0.001096
# 34      AIRLINE_ID20304  0.001795
# 35      AIRLINE_ID19393  0.001357
# 36      AIRLINE_ID19790  0.000940
# 37      AIRLINE_ID19805  0.001516

# %%
#using mean squared error and r2 here to get a sense of how well the model performs
from sklearn.metrics import mean_squared_error, r2_score
mse = mean_squared_error(y_test, preds)
r2 = r2_score(y_test, preds)
print 'Mean squared error for model : {0}\nR2 score for model: {1}'.format(mse, r2)
# Out:
# Mean squared error for model : 391.7946371
# R2 score for model: 0.759044160341

# %%
# quick scatterplot of scores vs actual outcomes
fig = plt.figure(figsize=(8,6))
ax = fig.add_subplot(1,1,1)
ax.scatter(x=y_test, y=preds)
ax.set_ylabel('Predicted Values')
ax.set_xlabel('Actual Values')
ax.set_xlim(min(y_test)-5, max(y_test)+5)
ax.set_ylim(min(preds)-5, max(preds)+5)
ax.set_title('Predicted vs. Actual Values of Flight Arrival Delays (minutes) in Test Set')
fig.savefig('chart.png')
